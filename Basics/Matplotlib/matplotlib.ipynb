# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.arange(0,5)
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
y =x**2
y
# Out:
# array([ 0,  1,  4,  9, 16])

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
x = np.linspace(0, 5, 11)
y = x ** 2+2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 2.  ,  2.25,  3.  ,  4.25,  6.  ,  8.25, 11.  , 14.25, 18.  ,
#        22.25, 27.  ])

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('X')
plt.ylabel('Y')

plt.title(r"$y=x^2+2$")
# plt.show()
# Out:
# Text(0.5, 1.0, '$y=x^2+2$')
